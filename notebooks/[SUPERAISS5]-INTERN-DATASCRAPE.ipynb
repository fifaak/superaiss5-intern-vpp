# %%
host_url = "https://ls.ene.cusmart.chula.ac.th/web-api/api/v1/report/demand?start=2025/07&node=174"

# %%
# !wget --user="demo-user" --password=12345678 "https://ls.ene.cusmart.chula.ac.th/web-api/api/v1/report/demand?start=2025/07&node=174"
# Out:
# --2025-07-14 15:42:21--  https://ls.ene.cusmart.chula.ac.th/web-api/api/v1/report/demand?start=2025/07&node=174
# Resolving ls.ene.cusmart.chula.ac.th (ls.ene.cusmart.chula.ac.th)... 94.74.116.125
# Connecting to ls.ene.cusmart.chula.ac.th (ls.ene.cusmart.chula.ac.th)|94.74.116.125|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Unknown authentication scheme.
#
# Username/Password Authentication Failed.
