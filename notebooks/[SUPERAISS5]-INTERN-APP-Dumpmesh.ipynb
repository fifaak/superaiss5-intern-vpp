# %%
# Download the main tileset files
# !wget "https://ls.ene.cusmart.chula.ac.th/api/tileset.json?v=2" -O tileset_v2.json
# !wget "https://ls.ene.cusmart.chula.ac.th/api/tileset.json?v=3" -O tileset_v3.json
# Out:
# --2025-07-18 12:42:53--  https://ls.ene.cusmart.chula.ac.th/api/tileset.json?v=2
# Resolving ls.ene.cusmart.chula.ac.th (ls.ene.cusmart.chula.ac.th)... 94.74.116.125
# Connecting to ls.ene.cusmart.chula.ac.th (ls.ene.cusmart.chula.ac.th)|94.74.116.125|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-07-18 12:42:55 ERROR 404: Not Found.
#
# --2025-07-18 12:42:55--  https://ls.ene.cusmart.chula.ac.th/api/tileset.json?v=3
# Resolving ls.ene.cusmart.chula.ac.th (ls.ene.cusmart.chula.ac.th)... 94.74.116.125
# Connecting to ls.ene.cusmart.chula.ac.th (ls.ene.cusmart.chula.ac.th)|94.74.116.125|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-07-18 12:42:56 ERROR 404: Not Found.
